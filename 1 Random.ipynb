# %%
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
sample_submission = pd.read_csv('data/Sample_Submission_Values.csv')

# %%
sample_submission
# Out:
#              filename        Superhero
# 0    superhero_test_1          ant_man
# 1    superhero_test_2        super_man
# 2    superhero_test_3         iron_man
# 3    superhero_test_4          bat_man
# 4    superhero_test_5  captain_america
# 5    superhero_test_6       spider_man
# 6    superhero_test_7             hulk
# 7    superhero_test_8         avengers
# 8    superhero_test_9    black_panther
# 9   superhero_test_10        cat_woman
# 10  superhero_test_11         aqua_man
# 11  superhero_test_12       ghostrider

# %%
superhero = sample_submission['Superhero'].values
superhero
# Out:
# array(['ant_man', 'super_man', 'iron_man', 'bat_man', 'captain_america',
#        'spider_man', 'hulk', 'avengers', 'black_panther', 'cat_woman',
#        'aqua_man', 'ghostrider'], dtype=object)

# %%
np.random.choice(superhero)
# Out:
# 'captain_america'

# %%
superhero_3375 = []
for i in tqdm(range(3375)):
    superhero_3375.append(np.random.choice(superhero))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 3375/3375 [00:00<00:00, 306753.98it/s]

# %%
len(superhero_3375)
# Out:
# 3375

# %%
sample_submission_3375 = pd.read_csv('data/Superhero_3375_SampleSubmission.csv')

# %%
sample_submission_3375.head()
# Out:
#                  filename        Superhero
# 0        superhero_test_1          ant_man
# 1        superhero_test_2        super_man
# 2        superhero_test_3         iron_man
# 3        superhero_test_4          bat_man
# 4        superhero_test_5  captain_america
# 5        superhero_test_6       spider_man
# 6        superhero_test_7             hulk
# 7        superhero_test_8         avengers
# 8        superhero_test_9    black_panther
# 9       superhero_test_10        cat_woman
# 10      superhero_test_11         aqua_man
# 11      superhero_test_12       ghostrider
# 12      superhero_test_13       ghostrider
# 13      superhero_test_14       ghostrider
# 14      superhero_test_15       ghostrider
# 15      superhero_test_16       ghostrider
# 16      superhero_test_17       ghostrider
# 17      superhero_test_18       ghostrider
# 18      superhero_test_19       ghostrider
# 19      superhero_test_20       ghostrider
# 20      superhero_test_21       ghostrider
# ...

# %%
sample_submission_3375['Superhero'] = superhero_3375

# %%
sample_submission_3375.head()
# Out:
#            filename      Superhero
# 0  superhero_test_1     spider_man
# 1  superhero_test_2      cat_woman
# 2  superhero_test_3      cat_woman
# 3  superhero_test_4      super_man
# 4  superhero_test_5  black_panther

# %%
sample_submission_3375.to_csv('submit.csv', index=False)

# %%
sample_submission_3375.to_csv?
